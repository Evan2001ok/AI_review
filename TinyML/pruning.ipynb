# %%
#pruning（剪枝）是通过裁剪模型参数和宽度来让模型更小消耗更少资源

# %%
#单pruning（剪枝）对模型准确率吧有所下降，pruning+Fine tuning(剪枝+微调)可以保证减少参数的同时保证准确率

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#单轮pruning+fine tuning减少的参数不够就多做几轮。直到大小满意且准确率达标

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#剪枝可以在不同颗粒度进行
#细粒度剪枝 (Fine-grained Pruning)，最高级别的灵活性，可以精确选择要剪掉的权重
#基于模式的剪枝（Pattern-Based Pruning）以规则的块状模式移除权重
#通道级剪枝 (Channel Pruning)根据重要性分数选择要保留的通道，移除不重要的通道

# %%
#element wise 剪枝标准为权重的绝对值，权重的绝对值越小越不重要用于剪枝

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#筛选式剪枝，多个wi的和绝对值比较，权重小的舍弃用于剪枝

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#缩放比例剪枝，整个层比较，层权重小的移除

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#如何找到pruning ratio（剪枝比例）
#方法1：使用敏感性分析，逐层应用不同剪枝率测试性能变化来找到每层的剪纸比例

# %% [markdown]
# ![image.png](data:image/png;base64,...)
